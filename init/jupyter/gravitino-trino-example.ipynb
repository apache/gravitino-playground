# %% [markdown]
# ## Gravitino Trino Example
#
# In this example, we will use `Jupyter` and the `Trino Python Client` to experience `Gravitino`.

# %%
# install trino python client and pandas
# %pip install trino pandas
# Out:
# Requirement already satisfied: trino in /opt/conda/lib/python3.11/site-packages (0.328.0)
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (19 kB)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.11/site-packages (from trino) (2.8.2)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from trino) (2023.3.post1)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from trino) (2.31.0)
# Requirement already satisfied: tzlocal in /opt/conda/lib/python3.11/site-packages (from trino) (5.2)
# Collecting numpy>=1.23.2 (from pandas)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil->trino) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->trino) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->trino) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->trino) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->trino) (2023.7.22)
# Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 14.1 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (14.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 10.5 MB/s eta 0:00:0000:0100:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 6.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from trino.dbapi import connect

# Create a Trino connector client
conn = connect(
    host="trino",
    port=8080,
    user="admin",
    catalog="catalog_hive",
    schema="http",
)

trino_client = conn.cursor()

# %% [markdown]
# ## Prepare
#
# Creates a schema named `catalog_hive.company` in Hive, with its location set to`hdfs://hive:9000/user/hive/warehouse/company.db` on HDFS.

# %%
trino_client.execute("""
CREATE SCHEMA catalog_hive.company
  WITH (location = 'hdfs://hive:9000/user/hive/warehouse/company.db')
""").fetchall()
# Out:
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 trino_client.execute("""
#       2 CREATE SCHEMA catalog_hive.company
#       3   WITH (location = 'hdfs://hive:9000/user/hive/warehouse/company.db')
#       4 """).fetchall()
#
# File /opt/conda/lib/python3.11/site-packages/trino/dbapi.py:589, in Cursor.execute(self, operation, params)
#     586 else:
#     587     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     588                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 589     self._iterator = iter(self._query.execute())
#     590 return self
#
# File /opt/conda/lib/python3.11/site-packages/trino/client.py:797, in TrinoQuery.execute(self, additional_http_headers)
#     795 # Execute should block until at least one row is received or query is finished or cancelled
#     796 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 797     self._result.rows += self.fetch()
#     798 return self._result
#
# File /opt/conda/lib/python3.11/site-packages/trino/client.py:817, in TrinoQuery.fetch(self)
#     815 except requests.exceptions.RequestException as e:
#     816     raise trino.exceptions.TrinoConnectionError("failed to fetch: {}".format(e))
# --> 817 status = self._request.process(response)
#     818 self._update_state(status)
#     819 if status.next_uri is None:
#
# File /opt/conda/lib/python3.11/site-packages/trino/client.py:595, in TrinoRequest.process(self, http_response)
#     593 response = http_response.json()
#     594 if "error" in response:
# --> 595     raise self._process_error(response["error"], response.get("id"))
#     597 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#     598     for prop in get_header_values(
#     599         http_response.headers, constants.HEADER_CLEAR_SESSION
#     600     ):
#
# TrinoUserError: TrinoUserError(type=USER_ERROR, name=SCHEMA_ALREADY_EXISTS, message="line 2:1: Schema 'catalog_hive.company' already exists", query_id=20240521_074722_00030_i27uz)

# %% [markdown]
# Displays the SQL command that was used to create the schema `catalog_hive.company`.

# %%
trino_client.execute("""
SHOW CREATE SCHEMA catalog_hive.company
""").fetchall()
# Out:
# [["CREATE SCHEMA catalog_hive.company\nWITH (\n   location = 'hdfs://hive:9000/user/hive/warehouse/company.db'\n)"]]

# %% [markdown]
# Create `employees` table

# %%
# Create Table
trino_client.execute(
"""
CREATE TABLE catalog_hive.company.employees
(
  name varchar,
  salary decimal(10,2)
)
WITH (
  format = 'TEXTFILE'
)
"""
).fetchall()
# Out:
# []

# %%
# Insert data
print(trino_client.execute("INSERT INTO catalog_hive.company.employees (name, salary) VALUES ('Sam Evans', 55000)").fetchall())
# Out:
# [[1]]

# %% [markdown]
# ## Simple queries
#
# Some simple query testing.

# %%
import pandas as pd

# Show employees table contents
df = pd.DataFrame(trino_client.execute("SELECT * FROM catalog_hive.company.employees").fetchall(), columns=['Name', 'Salary'])

# Display the DataFrame
df
# Out:
#         Name    Salary
# 0  Sam Evans  55000.00

# %%
# Execute the queries and convert the results directly to DataFrames
df_g = pd.DataFrame(trino_client.execute("SHOW SCHEMAS from catalog_hive").fetchall(), columns=['Schema'])
df_g
# Out:
#                Schema
# 0             company
# 1             default
# 2  information_schema
# 3               sales

# %%
h = trino_client.execute("DESCRIBE catalog_hive.company.employees").fetchall()
h
# Out:
# [['name', 'varchar', '', ''], ['salary', 'decimal(10,2)', '', '']]

# %%
df_i = pd.DataFrame(trino_client.execute("SHOW TABLES from catalog_hive.company").fetchall(), columns=['Tables'])
df_i
# Out:
#       Tables
# 0  employees

# %% [markdown]
# ## Cross-catalog queries
#
# In a company, there may be different departments using different data stacks. In this example, the HR department uses Apache Hive to store its data and the sales department uses PostgreSQL. You can run some interesting queries by joining the two departments' data together with Gravitino.
#
# To know which employee has the largest sales amount:

# %%
# Cross-catalog queries
cross_catalog = trino_client.execute("""
SELECT given_name, family_name, job_title, sum(total_amount) AS total_sales
FROM catalog_hive.sales.sales as s,
  catalog_postgres.hr.employees AS e
where s.employee_id = e.employee_id
GROUP BY given_name, family_name, job_title
ORDER BY total_sales DESC
LIMIT 1
""").fetchall()

# Convert the result to a DataFrame
df_j = pd.DataFrame(cross_catalog, columns=['Given Name', 'Family Name', 'Job Title', 'Total Sales'])

df_j
# Out:
#   Given Name Family Name        Job Title Total Sales
# 0       Dale     Lindsey  Sales Assistant     1809.87

# %% [markdown]
# To know the top customers who bought the most by state:

# %%
# Execute the query
k = trino_client.execute("""
SELECT customer_name, location, SUM(total_amount) AS total_spent
FROM catalog_hive.sales.sales AS s,
  catalog_hive.sales.stores AS l,
  catalog_hive.sales.customers AS c
WHERE s.store_id = l.store_id AND s.customer_id = c.customer_id
GROUP BY location, customer_name
ORDER BY location, SUM(total_amount) DESC
""").fetchall()

# Convert the result to a DataFrame
df_k = pd.DataFrame(k, columns=['Customer Name', 'Location', 'Total Spent'])

# Display the DataFrame
df_k
# Out:
#      Customer Name  Location Total Spent
# 0     Harriet Best    Kansas     4229.70
# 1    Lenore Wilder    Kansas     1594.84
# 2     Raya Mcguire    Kansas      349.92
# 3      Perry Tyler    Kansas       99.99
# 4         Mia Hahn    Kansas       94.97
# 5         Mia Hahn  Nebraska     2479.82
# 6     Raya Mcguire  Nebraska     1674.46
# 7   Erasmus Phelps  Nebraska     1553.79
# 8      Perry Tyler  Nebraska     1379.94
# 9     Harriet Best  Nebraska     1039.81
# 10   Lenore Wilder  Nebraska      129.98
# 11        Mia Hahn     Texas      279.98
# 12    Harriet Best     Texas      256.47
# 13  Erasmus Phelps     Texas      169.99
# 14    Raya Mcguire     Texas      135.98
# 15    Harriet Best   Vermont      719.88
# 16        Mia Hahn   Vermont      479.88
# 17     Perry Tyler   Vermont      299.98
# 18  Erasmus Phelps   Vermont      199.98

# %% [markdown]
# To know the employee's average performance rating and total sales:

# %%
# Execute the query
l = trino_client.execute("""
SELECT e.employee_id, given_name, family_name, AVG(rating) AS average_rating, SUM(total_amount) AS total_sales
FROM catalog_postgres.hr.employees AS e,
  catalog_postgres.hr.employee_performance AS p,
  catalog_hive.sales.sales AS s
WHERE e.employee_id = p.employee_id AND p.employee_id = s.employee_id
GROUP BY e.employee_id,  given_name, family_name
""").fetchall()

# Convert the result to a DataFrame
df_l = pd.DataFrame(l, columns=['Employee ID', 'Given Name', 'Family Name', 'Average Rating', 'Total Sales'])

# Display the DataFrame
df_l
# Out:
#     Employee ID Given Name Family Name  Average Rating Total Sales
# 0            10    Chelsea        Wade        5.000000      299.97
# 1            13       Risa      Barber        7.000000     1779.72
# 2            18    Carolyn    Bradshaw        7.000000     1029.90
# 3            19       Xyla          Le        4.000000      271.92
# 4            21      Carol      Decker        5.666667     2924.16
# 5            22     Quemby       Lucas        5.000000      897.47
# 6            28     Reuben       Rojas        4.250000     3799.68
# 7            29    Maxwell       Patel        7.000000     2759.88
# 8            41       Dale     Lindsey        7.000000     1809.87
# 9            42      Maite      Riddle        5.000000      485.43
# 10           44      Perry    Roberson        7.500000       49.98
# 11           49      Zephr        Long        6.000000      179.98
# 12            6     Jasper        Mack        4.000000     2207.64
# 13           11     Clarke     Sanders        5.833333     3329.34
# 14           15      Oprah        Noel        5.000000     1959.82
# 15           23     Phoebe      Forbes        4.250000     1919.76
# 16           25     Elijah     Burnett        3.800000      249.95
# 17           30     Edward        Reed        5.333333      168.00
# 18           32      Jesse   Contreras        5.000000     1049.76
# 19           46       Oleg        Tran       10.000000     1739.91
# 20           48   Mohammad    Caldwell        6.000000      256.47
# 21           52      Laura   Macdonald        7.166667     3839.76
